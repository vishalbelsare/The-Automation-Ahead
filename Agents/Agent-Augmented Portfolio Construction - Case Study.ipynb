# %% [markdown]
# # Agent-Augmented Portfolio Construction
#
# ## **Objective:**
#
# Design a separately managed account (SMA) or fund portfolio drawn from the S&P 500 constituents that achieves a dividend yield at least 3% higher than the S&P 500 benchmark, while maintaining a beta close to 1. The strategy aims to outperform the S&P 500 Dividend Aristocrats Index while preserving realistic sector exposures and applying sustainability and market-regime overlays.

# %% [markdown]
# # Step 1: Data Gathering and Cleaning Pipeline

# %%
pip install --upgrade yfinance pandas numpy tqdm
# Out:
# Requirement already satisfied: yfinance in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (0.2.63)
# Requirement already satisfied: pandas in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: numpy in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (2.3.0)
# Requirement already satisfied: tqdm in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: requests>=2.31 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (5.29.4)
# Requirement already satisfied: websockets>=13.0 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Requirement already satisfied: cffi>=1.12.0 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from curl_cffi>=0.7->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.4.0)
# Requirement already satisfied: pycparser in /Users/brianpisaneschi/Library/CloudStorage/OneDrive-CFAInstitute/Coding/GitHub/The-Automation-Ahead/conda-env/lib/python3.11/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import S&P 500 Constituents

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime, timedelta
import asyncio
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime, timedelta
from tqdm.asyncio import tqdm_asyncio   # just for a nice progress bar


def get_sp500_constituents() -> pd.DataFrame:
    """
    Return a DataFrame with the current S&P 500 ticker symbols and company names.
    """
    # Wikipedia’s first table on the page is always the constituents list
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    df = pd.read_html(url, header=0)[0]          # grab the first table

    # Clean up column names and tickers
    df.rename(columns={"Symbol": "Ticker"}, inplace=True)
    df["Ticker"] = df["Ticker"].str.replace(".", "-", regex=False)

    return df

def _fetch_one(ticker, div_growth_years, price_return_years):
    t = yf.Ticker(ticker)

    # 1) Dividend yield & payout ratio
    info      = t.fast_info
    div_yield = info.get("dividendYield")          # often None
    # fallback: dividendRate / price
    div_rate  = t.info.get("dividendRate", np.nan)
    price     = info.get("last_price") or t.info.get("previousClose")
    if pd.isna(div_yield) and div_rate and price:
        div_yield = div_rate / price

    payout    = t.info.get("payoutRatio")

    # 2) Dividend CAGR (same as before)
    divs    = t.dividends.copy()
    div_cagr = np.nan
    if len(divs) > 1:
        divs.index = divs.index.tz_localize(None)
        cutoff     = datetime.now() - timedelta(days=365*div_growth_years)
        past       = divs[divs.index < cutoff]
        recent     = divs[divs.index >= cutoff]
        if len(past) and len(recent):
            past_total   = past.resample("Y").sum().iloc[-1]
            recent_total = recent.resample("Y").sum().iloc[-1]
            if past_total > 0:
                div_cagr = (recent_total / past_total) ** (1/div_growth_years) - 1

    # 3) Price return
    hist        = t.history(period=f"{price_return_years}y")["Close"]
    price_ret   = (hist.iloc[-1] / hist.iloc[0] - 1) if len(hist) else np.nan

    # 4) Other ratios
    roe = t.info.get("returnOnEquity")
    dte = t.info.get("debtToEquity")

    return {
        "Ticker": ticker,
        "DividendYield": div_yield,
        "PayoutRatio": payout,
        f"DivCAGR_{div_growth_years}y": div_cagr,
        f"PriceReturn_{price_return_years}y": price_ret,
        "ROE": roe,
        "DebtToEquity": dte,
    }

# ---------- async wrapper ----------
async def get_financial_metrics_async(tickers,
                                      div_growth_years: int = 5,
                                      price_return_years: int = 5,
                                      max_workers: int = 20) -> pd.DataFrame:
    """
    Concurrently fetch metrics for many tickers using asyncio + ThreadPoolExecutor.
    """
    if isinstance(tickers, str):
        tickers = [tickers]

    loop = asyncio.get_running_loop()
    rows = []

    with ThreadPoolExecutor(max_workers=max_workers) as pool:
        tasks = [
            loop.run_in_executor(
                pool,
                _fetch_one,
                tk,
                div_growth_years,
                price_return_years
            )
            for tk in tickers
        ]

        # tqdm_asyncio gives a progress bar; remove if you don't want it
        for result in tqdm_asyncio.as_completed(tasks, total=len(tasks)):
            rows.append(await result)

    return pd.DataFrame(rows).set_index("Ticker")

# ---------------- example usage ----------------

from time import perf_counter

sp500 = get_sp500_constituents()["Ticker"].tolist()[:50]   # try 50 first
metrics_df = await get_financial_metrics_async(
    sp500,
    div_growth_years=3,
    price_return_years=3,
    max_workers=20        # tune as you wish
)
metrics_df.head().round(4)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]/var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
#   2%|▏         | 1/50 [00:06<05:33,  6.82s/it]/var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
#   4%|▍         | 2/50 [00:06<02:19,  2.90s/it]/var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
#  38%|███▊      | 19/50 [00:08<00:06,  5.16it/s]/var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
#  54%|█████▍    | 27/50 [00:11<00:05,  4.24it/s]/var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
#  72%|███████▏  | 36/50 [00:12<00:02,  5.86it/s]/var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:48: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   past_total   = past.resample("Y").sum().iloc[-1]
# /var/folders/3g/79hl_7s12859plnmqc8l6nrw0000gp/T/ipykernel_81354/2990045608.py:49: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   recent_total = recent.resample("Y").sum().iloc[-1]
# 100%|██████████| 50/50 [00:15<00:00,  3.29it/s]
#         DividendYield  PayoutRatio  DivCAGR_3y  PriceReturn_3y     ROE  \
# Ticker
# ABNB              NaN       0.0000         NaN          0.3041  0.3206
# ALLE           0.0150       0.2739     -0.1464          0.4955  0.4205
# ALGN              NaN       0.0000         NaN         -0.2395  0.1084
# AKAM              NaN       0.0000         NaN         -0.1320  0.0982
# ABBV           0.0344       2.6880      0.0517          0.4482  0.8840
#
#         DebtToEquity
# Ticker
# ABNB          28.726
# ALLE         133.636
# ALGN           3.124
# AKAM         100.746
# ABBV        4789.603

# %%
metrics_df
# Out:
#         DividendYield  PayoutRatio  DivCAGR_3y  PriceReturn_3y      ROE  \
# Ticker
# ABNB              NaN       0.0000         NaN        0.304097  0.32060
# ALLE         0.014989       0.2739   -0.146405        0.495522  0.42052
# ALGN              NaN       0.0000         NaN       -0.239460  0.10843
# AKAM              NaN       0.0000         NaN       -0.132046  0.09821
# ABBV         0.034371       2.6880    0.051659        0.448237  0.88400
# GOOGL        0.004752       0.0893         NaN        0.586865  0.34789
# ACN          0.018834       0.4567    0.151233        0.158925  0.26965
# AMD               NaN       0.0000         NaN        0.516887  0.03904
# ARE          0.072687       6.8947    0.047029       -0.384810  0.01476
# A            0.008318       0.2384   -0.161054        0.041317  0.18883
# ALB          0.026575       0.5797    0.008369       -0.713088 -0.09992
# ADBE              NaN       0.0000         NaN        0.054244  0.52254
# ALL          0.020039       0.2568    0.055667        0.751752  0.19723
# AES          0.061082       0.3769    0.036617       -0.403621  0.05583
# AFL          0.022586       0.3235    0.131851        1.016538  0.14408
# APD          0.025532       1.0231    0.300105        0.240344  0.09579
# ABT          0.017611       0.2909    0.078743        0.343342  0.30649
# MMM          0.020128       0.3524   -0.163198        0.481577  0.93824
# AOS          0.021144       0.3687    0.066859        0.262906  0.27970
# LNT          0.033576       0.6716    0.058087        0.206462  0.10712
# AMZN              NaN       0.0000         NaN        0.976629  0.25240
# AMCR         0.055495       0.9050   -0.189040       -0.131423  0.20796
# AME          0.006942       0.1882    0.121105        0.653489  0.14964
# AWK          0.023564       0.5574    0.081878        0.116775  0.10428
# AMP          0.012478       0.2012    0.089744        1.184162  0.58108
# AMGN         0.032210       0.8323    0.070512        0.338172  1.05673
# GOOG         0.004721       0.0893         NaN        0.591604  0.34789
# AEE          0.029955       0.6031    0.063658        0.256062  0.10159
# APH          0.007080       0.2937    0.181666        2.010714  0.27526
# AMT          0.031631       1.0615    0.063076       -0.039210  0.28421
# MO           0.069388       0.6779    0.042604        0.653004      NaN
# APO          0.015213       0.3229    0.067434        1.810072  0.18686
# APA          0.048780       0.3584    0.259921       -0.433911  0.26176
# ANSS              NaN       0.0000         NaN        0.431139  0.10230
# AIG          0.021067       0.3902    0.099207        0.726375  0.05744
# AEP          0.036503       0.6988    0.060383        0.267685  0.10421
# AON          0.008513       0.2334    0.351264        0.404487  0.72012
# AAPL         0.005241       0.1558    0.042604        0.463007  1.38015
# ADI          0.017084       1.0190    0.092129        0.617894  0.05213
# AXP          0.011148       0.2039    0.169607        1.104839  0.34273
# ANET              NaN       0.0000         NaN        2.823084  0.33681
# ACGL              NaN       0.0000         NaN        1.167964  0.18415
# APTV              NaN       0.0000         NaN       -0.254604  0.15237
# AIZ          0.015999       0.2371    0.055667        0.218297  0.13204
# AMAT         0.010422       0.1946    0.198145        0.879561  0.36372
# AJG          0.008219       0.3781    0.084212        1.095537  0.09298
# ADM          0.037666       0.7077    0.084351       -0.255528  0.05888
# T            0.039685       0.6810   -0.113476        0.656990  0.10885
# ATO          0.022889       0.4679    0.085601        0.557764  0.09186
# ADSK              NaN       0.0000         NaN        0.778823  0.42361
#
#         DebtToEquity
# Ticker
# ABNB          28.726
# ALLE         133.636
# ALGN           3.124
# AKAM         100.746
# ABBV        4789.603
# GOOGL          8.254
# ACN           26.706
# AMD            8.174
# ARE           61.193
# A             60.039
# ALB           35.757
# ADBE          57.329
# ALL           36.672
# AES          361.561
# AFL           42.513
# APD           98.527
# ABT           27.087
# MMM          312.492
# AOS           15.945
# LNT          149.852
# AMZN          51.641
# AMCR         241.410
# AME           21.761
# AWK          137.735
# AMP           74.235
# AMGN         924.456
# GOOG           8.254
# AEE          158.916
# APH           69.096
# AMT          446.681
# MO               NaN
# APO           90.490
# APA           84.961
# ANSS          13.932
# AIG           21.112
# AEP          171.503
# AON          254.468
# AAPL         146.994
# ADI           20.620
# AXP          170.351
# ANET             NaN
# ACGL          12.662
# APTV          91.193
# AIZ           39.809
# AMAT          35.177
# AJG           60.048
# ADM           55.504
# T            119.246
# ATO           64.747
# ADSK          97.211
